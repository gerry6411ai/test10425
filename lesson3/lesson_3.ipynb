�\n羅佩樺\n陳家維\n張莉雯\n高俊男\n林冠蕙\n王品星\n吳孟穎\n黃雅慧\n馮耀中\n元延辛\n王坤安\n陳慧君\n張伊映\n林士凱\n蘇婷婷\n陳淑萍\n林玉佩\n謝貞妃\n杜儀鳳\n陳倩妮\n胡淑貞\n楊偉翔\n姜琬婷\n張雅芬\n葉祖雄\n沈心利\n彭虹屏\n余宗儒\n李立偉\n臧怡君\n吳振瑋\n陳建豪\n蕭怡伶\n周芷蓁\n黃偉剛\n黃婷婷\n郎慧萍\n林昱芳\n趙宛真\n白世宏
# ...

# %%
import random
with open('names.txt',encoding='utf-8') as file:
     content:str= file.read()
     names:list[str]=content.split()

     random_names:list[str]= random.sample(names, 3)
     random_names

# %%
import requests

url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=540e2ca4-41e1-4186-8497-fdd67024ac44&limit=1000&sort=ImportDate%20desc&format=CSV'
response = requests.get(url, verify=False)  # 測試時可以這樣寫
print(response.text)
# Out:
# sitename,county,aqi,pollutant,status,so2,co,o3,o3_8hr,pm10,pm2.5,no2,nox,no,wind_speed,wind_direc,publishtime,co_8hr,pm2.5_avg,pm10_avg,so2_avg,longitude,latitude,siteid
# 基隆,基隆市,54,細懸浮微粒,普通,1.3,0.2,54,55,5,3,2,3.4,0.9,2.1,95,"2025/05/08 13:00:00",0.2,13.5,,0,121.760056,25.129167,1
# 汐止,新北市,46,,良好,0.4,0.2,52,38,4,3,3,5.1,1.3,1.3,201,"2025/05/08 13:00:00",0.2,11.4,22,0,121.64081,25.06624,2
# 新店,新北市,53,細懸浮微粒,普通,0.5,0.23,55,55,21,12,4,5.7,1.2,2.1,121,"2025/05/08 13:00:00",0.2,13.4,29,0,121.537778,24.977222,4
# 土城,新北市,56,細懸浮微粒,普通,0.4,0.24,54,48,23,14,5,6.6,1.2,2.8,330,"2025/05/08 13:00:00",0.2,14.4,25,0,121.451861,24.982528,5
# 板橋,新北市,46,,良好,1.3,0.3,56,50,16,4,8,10.7,2.1,1.7,46,"2025/05/08 13:00:00",0.3,10.2,27,0,121.458667,25.012972,6
# 新莊,新北市,51,細懸浮微粒,普通,0.5,0.24,60,44,13,6,7,9.3,2.1,2.2,86,"2025/05/08 13:00:00",0.3,12.5,30,0,121.4325,25.037972,7
# 菜寮,新北市,59,細懸浮微粒,普通,0.7,0.27,56,50,15,10,7,9.2,1.6,2.8,78,"2025/05/08 13:00:00",0.3,15.4,29,0,121.481028,25.06895,8
# ...
